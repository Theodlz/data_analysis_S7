# %% [markdown]
# # LSTM PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import os

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error,r2_score
from tensorflow.keras.callbacks import TensorBoard
# Out:
# 2021-12-02 16:04:55.984115: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-02 16:04:55.984134: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = pd.read_csv(os.getcwd()+"/pre_processing/dataset_traite.csv", sep=',', parse_dates=["DateTime"])

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm.head()
# Out:
#                      Global_active_power     Voltage  Global_intensity  \
# DateTime
# 2006-12-16 17:00:00             4.222889  234.643889         18.100000
# 2006-12-16 18:00:00             3.632200  234.580167         15.600000
# 2006-12-16 19:00:00             3.400233  233.232500         14.503333
# 2006-12-16 20:00:00             3.268567  234.071500         13.916667
# 2006-12-16 21:00:00             3.056467  237.158667         13.046667
#
#                      Sub_metering_1  Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16 17:00:00             0.0        0.527778       16.861111    4.6
# 2006-12-16 18:00:00             0.0        6.716667       16.866667    4.6
# 2006-12-16 19:00:00             0.0        1.433333       16.683333    4.6
# 2006-12-16 20:00:00             0.0        0.000000       16.783333    4.6
# 2006-12-16 21:00:00             0.0        0.416667       17.216667    4.6

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
df_lstm[df_lstm.columns] = scaler.fit_transform(df_lstm[df_lstm.columns])
df_lstm.describe()
# Out:
#        Global_active_power       Voltage  Global_intensity  Sub_metering_1  \
# count         34685.000000  34685.000000      34685.000000    34685.000000
# mean             -0.699531      0.151530         -0.704330       -0.953650
# std               0.277138      0.228798          0.267858        0.145356
# min              -1.000000     -1.000000         -1.000000       -1.000000
# 25%              -0.931847      0.026604         -0.927068       -1.000000
# 50%              -0.783600      0.158825         -0.785270       -1.000000
# 75%              -0.550742      0.292273         -0.565280       -1.000000
# max               1.000000      1.000000          1.000000        1.000000
#
#        Sub_metering_2  Sub_metering_3         avg_t
# count    34685.000000    34685.000000  34951.000000
# mean        -0.944071       -0.401244     -0.212083
# std          0.179511        0.677681      0.391636
# min         -1.000000       -1.000000     -1.000000
# 25%         -1.000000       -0.939675     -0.514793
# 50%         -0.985642       -0.845321     -0.242604
# 75%         -0.971285        0.293117      0.076923
# max          1.000000        1.000000      1.000000

# %%
# def data_to_supervised(df, steps_ahead = 1, col_to_predict="Global_active_power"):
#     data = pd.DataFrame(df)
#     n_vars = data.shape[1]
#     columns = []
#     columns.append(data.shift(0))
#     # temp = data.shift(0)
#     columns.append(data.shift(-steps_ahead)[col_to_predict])
#     df_labeled = pd.concat(columns, axis=1)
#     names = [col + "(t-1)" for col in df.columns]
#     names.append(f"{col_to_predict}(t)")
#     print(names)
#     df_labeled.columns = names
#     df_labeled.dropna(inplace=True)
    
#     return df_labeled

def data_to_supervised(df, col_to_predict="Global_active_power"):
    data = pd.DataFrame(df)
    n_vars = data.shape[1]
    columns = []
    columns.append(data.shift(1))
    # temp = data.shift(0)
    columns.append(data.shift(0)[col_to_predict])
    df_labeled = pd.concat(columns, axis=1)
    names = [col + "(t-1)" for col in df.columns]
    names.append(f"{col_to_predict}(t)")
    print(names)
    df_labeled.columns = names
    df_labeled.dropna(inplace=True)
    
    return df_labeled

# %%
df_lstm = data_to_supervised(df_lstm)
df_lstm.head(5)
# Out:
# ['Global_active_power(t-1)', 'Voltage(t-1)', 'Global_intensity(t-1)', 'Sub_metering_1(t-1)', 'Sub_metering_2(t-1)', 'Sub_metering_3(t-1)', 'avg_t(t-1)', 'Global_active_power(t)']
#                      Global_active_power(t-1)  Voltage(t-1)  \
# DateTime
# 2006-12-16 18:00:00                  0.273632     -0.324109
# 2006-12-16 19:00:00                  0.090090     -0.328998
# 2006-12-16 20:00:00                  0.018012     -0.432397
# 2006-12-16 21:00:00                 -0.022901     -0.368025
# 2006-12-16 22:00:00                 -0.088806     -0.131166
#
#                      Global_intensity(t-1)  Sub_metering_1(t-1)  \
# DateTime
# 2006-12-16 18:00:00               0.262315                 -1.0
# 2006-12-16 19:00:00               0.082975                 -1.0
# 2006-12-16 20:00:00               0.004304                 -1.0
# 2006-12-16 21:00:00              -0.037781                 -1.0
# 2006-12-16 22:00:00              -0.100191                 -1.0
#
#                      Sub_metering_2(t-1)  Sub_metering_3(t-1)  avg_t(t-1)  \
# DateTime
# 2006-12-16 18:00:00            -0.977267             0.564836    0.029586
# 2006-12-16 19:00:00            -0.710696             0.565352    0.029586
# 2006-12-16 20:00:00            -0.938263             0.548337    0.029586
# 2006-12-16 21:00:00            -1.000000             0.557618    0.029586
# 2006-12-16 22:00:00            -0.982053             0.597834    0.029586
#
#                      Global_active_power(t)
# DateTime
# 2006-12-16 18:00:00                0.090090
# 2006-12-16 19:00:00                0.018012
# 2006-12-16 20:00:00               -0.022901
# 2006-12-16 21:00:00               -0.088806
# 2006-12-16 22:00:00               -0.354891

# %%
values = df_lstm.values

trainsize = 0.8
n_rows = round(len(values)*trainsize)
print(f"Taille du trainset : {n_rows}")

train = values[:n_rows, :]
test = values[n_rows:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D format as expected by LSTMs [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# Taille du trainset : 27661
# (27661, 1, 2) (27661,) (6915, 1, 2) (6915,)

# %%
model = Sequential()
#recurrent_activation ='selu' # 1er place
#recurrent_activation ='softsign' # 2e place

model.add(LSTM(125, input_shape=(train_X.shape[1], train_X.shape[2]),recurrent_activation ='sigmoid',activation='tanh',return_sequences=False))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh',return_sequences=True))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh'))
#model.add(Dropout(0.2))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

model.compile(loss='mean_absolute_error', optimizer='adam')
#model.compile(optimizer=tensorflow.keras.optimizers.SGD(learning_rate=0.001),
             # loss=tensorflow.keras.losses.MeanSquaredError(),
             # metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 125)               64000
#
#  dense_20 (Dense)            (None, 1)                 126
#
# =================================================================
# Total params: 64,126
# Trainable params: 64,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=75, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/75
# 396/396 - 2s - loss: 0.1857 - val_loss: 0.1177 - 2s/epoch - 5ms/step
# Epoch 2/75
# 396/396 - 1s - loss: 0.1326 - val_loss: 0.1158 - 889ms/epoch - 2ms/step
# Epoch 3/75
# 396/396 - 1s - loss: 0.1324 - val_loss: 0.1157 - 886ms/epoch - 2ms/step
# Epoch 4/75
# 396/396 - 1s - loss: 0.1322 - val_loss: 0.1157 - 887ms/epoch - 2ms/step
# Epoch 5/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 889ms/epoch - 2ms/step
# Epoch 6/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 890ms/epoch - 2ms/step
# Epoch 7/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 889ms/epoch - 2ms/step
# Epoch 8/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 884ms/epoch - 2ms/step
# Epoch 9/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1155 - 883ms/epoch - 2ms/step
# Epoch 10/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 888ms/epoch - 2ms/step
# Epoch 11/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 895ms/epoch - 2ms/step
# Epoch 12/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1154 - 880ms/epoch - 2ms/step
# Epoch 13/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 14/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 15/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 16/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1153 - 897ms/epoch - 2ms/step
# Epoch 17/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1154 - 887ms/epoch - 2ms/step
# Epoch 18/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 874ms/epoch - 2ms/step
# Epoch 19/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1155 - 895ms/epoch - 2ms/step
# Epoch 20/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 21/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 894ms/epoch - 2ms/step
# Epoch 22/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 882ms/epoch - 2ms/step
# Epoch 23/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 884ms/epoch - 2ms/step
# Epoch 24/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 25/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 893ms/epoch - 2ms/step
# Epoch 26/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 891ms/epoch - 2ms/step
# Epoch 27/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 898ms/epoch - 2ms/step
# Epoch 28/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 897ms/epoch - 2ms/step
# Epoch 29/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 30/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 31/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1150 - 886ms/epoch - 2ms/step
# Epoch 32/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 33/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 34/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 35/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 884ms/epoch - 2ms/step
# Epoch 36/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 868ms/epoch - 2ms/step
# Epoch 37/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 38/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 39/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 891ms/epoch - 2ms/step
# Epoch 40/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 41/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 42/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 43/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 44/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 884ms/epoch - 2ms/step
# Epoch 45/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 899ms/epoch - 2ms/step
# Epoch 46/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 891ms/epoch - 2ms/step
# Epoch 47/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 48/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 49/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 885ms/epoch - 2ms/step
# Epoch 50/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 51/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 878ms/epoch - 2ms/step
# Epoch 52/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 53/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 880ms/epoch - 2ms/step
# Epoch 54/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 888ms/epoch - 2ms/step
# Epoch 55/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 889ms/epoch - 2ms/step
# Epoch 56/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 882ms/epoch - 2ms/step
# Epoch 57/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1148 - 882ms/epoch - 2ms/step
# Epoch 58/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 59/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 60/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 61/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 62/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 63/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 64/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 881ms/epoch - 2ms/step
# Epoch 65/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 66/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 881ms/epoch - 2ms/step
# Epoch 67/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1148 - 883ms/epoch - 2ms/step
# Epoch 68/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 885ms/epoch - 2ms/step
# Epoch 69/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 70/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 888ms/epoch - 2ms/step
# Epoch 71/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 72/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 890ms/epoch - 2ms/step
# Epoch 73/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 887ms/epoch - 2ms/step
# Epoch 74/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 75/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 875ms/epoch - 2ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
size = df_lstm.shape[1]-1
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], size))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.565

# %%
# print("test")
# Out:
# test

# %%
import sklearn
r2 = sklearn.metrics.r2_score(inv_y, inv_yhat)
print(r2)
r_adjusted = 1 - ( 1-r2 ) * ( len(test_y) - 1 ) / ( len(test_y) - test_X.shape[1] - 1 )
print(r_adjusted)
# Out:
# 0.4282967339033622
# 0.4281313105046074

# %%
aa=[x for x in range(100)]
plt.figure(figsize=(40,10))
plt.plot(aa, inv_y[:100], marker='.', label="actual")
plt.plot(aa, inv_yhat[:100], 'r', label="prediction")
plt.ylabel(df.columns[1], size=15)
plt.xlabel('Time step for first 500 hours', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm2 = df_lstm.resample('d').mean()
df_lstm2.head(5)
# Out:
#             Global_active_power     Voltage  Global_intensity  Sub_metering_1  \
# DateTime
# 2006-12-16             3.120298  236.152341         13.369524        0.000000
# 2006-12-17             2.354486  240.087028          9.999028        1.411806
# 2006-12-18             1.530435  241.231694          6.421667        0.738194
# 2006-12-19             1.157079  241.999313          4.926389        0.582639
# 2006-12-20             1.545658  242.308063          6.467361        0.000000
#
#             Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16        1.330159       12.692063   4.60
# 2006-12-17        2.907639        9.264583   2.40
# 2006-12-18        1.820139        9.734722   3.40
# 2006-12-19        5.279167        4.303472   1.25
# 2006-12-20        1.838889        9.765972   2.35

# %% [markdown]
# # LSTM PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import os

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error,r2_score
from tensorflow.keras.callbacks import TensorBoard

# %%
df = pd.read_csv(os.getcwd()+"/pre_processing/dataset_traite.csv", sep=',', parse_dates=["DateTime"])

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm.head()
# Out:
#                      Global_active_power     Voltage  Global_intensity  \
# DateTime
# 2006-12-16 17:00:00             4.222889  234.643889         18.100000
# 2006-12-16 18:00:00             3.632200  234.580167         15.600000
# 2006-12-16 19:00:00             3.400233  233.232500         14.503333
# 2006-12-16 20:00:00             3.268567  234.071500         13.916667
# 2006-12-16 21:00:00             3.056467  237.158667         13.046667
#
#                      Sub_metering_1  Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16 17:00:00             0.0        0.527778       16.861111    4.6
# 2006-12-16 18:00:00             0.0        6.716667       16.866667    4.6
# 2006-12-16 19:00:00             0.0        1.433333       16.683333    4.6
# 2006-12-16 20:00:00             0.0        0.000000       16.783333    4.6
# 2006-12-16 21:00:00             0.0        0.416667       17.216667    4.6

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
df_lstm[df_lstm.columns] = scaler.fit_transform(df_lstm[df_lstm.columns])
df_lstm.describe()
# Out:
#        Global_active_power       Voltage  Global_intensity  Sub_metering_1  \
# count         34685.000000  34685.000000      34685.000000    34685.000000
# mean             -0.699531      0.151530         -0.704330       -0.953650
# std               0.277138      0.228798          0.267858        0.145356
# min              -1.000000     -1.000000         -1.000000       -1.000000
# 25%              -0.931847      0.026604         -0.927068       -1.000000
# 50%              -0.783600      0.158825         -0.785270       -1.000000
# 75%              -0.550742      0.292273         -0.565280       -1.000000
# max               1.000000      1.000000          1.000000        1.000000
#
#        Sub_metering_2  Sub_metering_3         avg_t
# count    34685.000000    34685.000000  34951.000000
# mean        -0.944071       -0.401244     -0.212083
# std          0.179511        0.677681      0.391636
# min         -1.000000       -1.000000     -1.000000
# 25%         -1.000000       -0.939675     -0.514793
# 50%         -0.985642       -0.845321     -0.242604
# 75%         -0.971285        0.293117      0.076923
# max          1.000000        1.000000      1.000000

# %%
def data_to_supervised(df, col_to_predict="Global_active_power"):
    data = pd.DataFrame(df)
    n_vars = data.shape[1]
    columns = []
    columns.append(data.shift(0))
    # temp = data.shift(0)
    columns.append(data.shift(-1)[col_to_predict])
    df_labeled = pd.concat(columns, axis=1)
    names = [col + "(t-1)" for col in df.columns]
    names.append(f"{col_to_predict}(t)")
    print(names)
    df_labeled.columns = names
    df_labeled.dropna(inplace=True)
    
    return df_labeled

# %%
df_lstm = data_to_supervised(df_lstm)
df_lstm.head(3)
# Out:
# ['Global_active_power(t-1)', 'Voltage(t-1)', 'Global_intensity(t-1)', 'Sub_metering_1(t-1)', 'Sub_metering_2(t-1)', 'Sub_metering_3(t-1)', 'avg_t(t-1)', 'Global_active_power(t)']
#                      Global_active_power(t-1)  Voltage(t-1)  \
# DateTime
# 2006-12-16 17:00:00                  0.273632     -0.324109
# 2006-12-16 18:00:00                  0.090090     -0.328998
# 2006-12-16 19:00:00                  0.018012     -0.432397
#
#                      Global_intensity(t-1)  Sub_metering_1(t-1)  \
# DateTime
# 2006-12-16 17:00:00               0.262315                 -1.0
# 2006-12-16 18:00:00               0.082975                 -1.0
# 2006-12-16 19:00:00               0.004304                 -1.0
#
#                      Sub_metering_2(t-1)  Sub_metering_3(t-1)  avg_t(t-1)  \
# DateTime
# 2006-12-16 17:00:00            -0.977267             0.564836    0.029586
# 2006-12-16 18:00:00            -0.710696             0.565352    0.029586
# 2006-12-16 19:00:00            -0.938263             0.548337    0.029586
#
#                      Global_active_power(t)
# DateTime
# 2006-12-16 17:00:00                0.090090
# 2006-12-16 18:00:00                0.018012
# 2006-12-16 19:00:00               -0.022901

# %%
values = df_lstm.values

trainsize = 0.8
n_rows = round(len(values)*trainsize)
print(f"Taille du trainset : {n_rows}")

train = values[:n_rows, :]
test = values[n_rows:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D format as expected by LSTMs [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# Taille du trainset : 27661
# (27661, 1, 7) (27661,) (6915, 1, 7) (6915,)

# %%
model = Sequential()
#recurrent_activation ='selu' # 1er place
#recurrent_activation ='softsign' # 2e place

model.add(LSTM(125, input_shape=(train_X.shape[1], train_X.shape[2]),recurrent_activation ='sigmoid',activation='tanh',return_sequences=False))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh',return_sequences=True))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh'))
#model.add(Dropout(0.2))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

model.compile(loss='mean_absolute_error', optimizer='adam')
#model.compile(optimizer=tensorflow.keras.optimizers.SGD(learning_rate=0.001),
             # loss=tensorflow.keras.losses.MeanSquaredError(),
             # metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 125)               64000
#
#  dense_20 (Dense)            (None, 1)                 126
#
# =================================================================
# Total params: 64,126
# Trainable params: 64,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=75, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/75
# 396/396 - 2s - loss: 0.1857 - val_loss: 0.1177 - 2s/epoch - 5ms/step
# Epoch 2/75
# 396/396 - 1s - loss: 0.1326 - val_loss: 0.1158 - 889ms/epoch - 2ms/step
# Epoch 3/75
# 396/396 - 1s - loss: 0.1324 - val_loss: 0.1157 - 886ms/epoch - 2ms/step
# Epoch 4/75
# 396/396 - 1s - loss: 0.1322 - val_loss: 0.1157 - 887ms/epoch - 2ms/step
# Epoch 5/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 889ms/epoch - 2ms/step
# Epoch 6/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 890ms/epoch - 2ms/step
# Epoch 7/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 889ms/epoch - 2ms/step
# Epoch 8/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 884ms/epoch - 2ms/step
# Epoch 9/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1155 - 883ms/epoch - 2ms/step
# Epoch 10/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 888ms/epoch - 2ms/step
# Epoch 11/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 895ms/epoch - 2ms/step
# Epoch 12/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1154 - 880ms/epoch - 2ms/step
# Epoch 13/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 14/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 15/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 16/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1153 - 897ms/epoch - 2ms/step
# Epoch 17/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1154 - 887ms/epoch - 2ms/step
# Epoch 18/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 874ms/epoch - 2ms/step
# Epoch 19/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1155 - 895ms/epoch - 2ms/step
# Epoch 20/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 21/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 894ms/epoch - 2ms/step
# Epoch 22/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 882ms/epoch - 2ms/step
# Epoch 23/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 884ms/epoch - 2ms/step
# Epoch 24/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 25/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 893ms/epoch - 2ms/step
# Epoch 26/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 891ms/epoch - 2ms/step
# Epoch 27/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 898ms/epoch - 2ms/step
# Epoch 28/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 897ms/epoch - 2ms/step
# Epoch 29/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 30/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 31/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1150 - 886ms/epoch - 2ms/step
# Epoch 32/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 33/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 34/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 35/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 884ms/epoch - 2ms/step
# Epoch 36/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 868ms/epoch - 2ms/step
# Epoch 37/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 38/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 39/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 891ms/epoch - 2ms/step
# Epoch 40/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 41/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 42/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 43/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 44/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 884ms/epoch - 2ms/step
# Epoch 45/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 899ms/epoch - 2ms/step
# Epoch 46/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 891ms/epoch - 2ms/step
# Epoch 47/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 48/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 49/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 885ms/epoch - 2ms/step
# Epoch 50/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 51/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 878ms/epoch - 2ms/step
# Epoch 52/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 53/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 880ms/epoch - 2ms/step
# Epoch 54/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 888ms/epoch - 2ms/step
# Epoch 55/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 889ms/epoch - 2ms/step
# Epoch 56/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 882ms/epoch - 2ms/step
# Epoch 57/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1148 - 882ms/epoch - 2ms/step
# Epoch 58/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 59/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 60/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 61/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 62/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 63/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 64/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 881ms/epoch - 2ms/step
# Epoch 65/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 66/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 881ms/epoch - 2ms/step
# Epoch 67/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1148 - 883ms/epoch - 2ms/step
# Epoch 68/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 885ms/epoch - 2ms/step
# Epoch 69/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 70/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 888ms/epoch - 2ms/step
# Epoch 71/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 72/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 890ms/epoch - 2ms/step
# Epoch 73/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 887ms/epoch - 2ms/step
# Epoch 74/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 75/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 875ms/epoch - 2ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
size = df_lstm.shape[1]-1
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], size))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.565

# %%
# print("test")
# Out:
# test

# %%
import sklearn
r2 = sklearn.metrics.r2_score(inv_y, inv_yhat)
print(r2)
r_adjusted = 1 - ( 1-r2 ) * ( len(test_y) - 1 ) / ( len(test_y) - test_X.shape[1] - 1 )
print(r_adjusted)
# Out:
# 0.4282967339033622
# 0.4281313105046074

# %%
aa=[x for x in range(100)]
plt.figure(figsize=(40,10))
plt.plot(aa, inv_y[:100], marker='.', label="actual")
plt.plot(aa, inv_yhat[:100], 'r', label="prediction")
plt.ylabel(df.columns[1], size=15)
plt.xlabel('Time step for first 500 hours', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm2 = df_lstm.resample('d').mean()
df_lstm2.head(5)
# Out:
#             Global_active_power     Voltage  Global_intensity  Sub_metering_1  \
# DateTime
# 2006-12-16             3.120298  236.152341         13.369524        0.000000
# 2006-12-17             2.354486  240.087028          9.999028        1.411806
# 2006-12-18             1.530435  241.231694          6.421667        0.738194
# 2006-12-19             1.157079  241.999313          4.926389        0.582639
# 2006-12-20             1.545658  242.308063          6.467361        0.000000
#
#             Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16        1.330159       12.692063   4.60
# 2006-12-17        2.907639        9.264583   2.40
# 2006-12-18        1.820139        9.734722   3.40
# 2006-12-19        5.279167        4.303472   1.25
# 2006-12-20        1.838889        9.765972   2.35

# %% [markdown]
# # LSTM PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import os

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error,r2_score
from tensorflow.keras.callbacks import TensorBoard
# Out:
# 2021-12-02 16:04:55.984115: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-02 16:04:55.984134: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = pd.read_csv(os.getcwd()+"/pre_processing/dataset_traite.csv", sep=',', parse_dates=["DateTime"])

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm.head()
# Out:
#                      Global_active_power     Voltage  Global_intensity  \
# DateTime
# 2006-12-16 17:00:00             4.222889  234.643889         18.100000
# 2006-12-16 18:00:00             3.632200  234.580167         15.600000
# 2006-12-16 19:00:00             3.400233  233.232500         14.503333
# 2006-12-16 20:00:00             3.268567  234.071500         13.916667
# 2006-12-16 21:00:00             3.056467  237.158667         13.046667
#
#                      Sub_metering_1  Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16 17:00:00             0.0        0.527778       16.861111    4.6
# 2006-12-16 18:00:00             0.0        6.716667       16.866667    4.6
# 2006-12-16 19:00:00             0.0        1.433333       16.683333    4.6
# 2006-12-16 20:00:00             0.0        0.000000       16.783333    4.6
# 2006-12-16 21:00:00             0.0        0.416667       17.216667    4.6

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
df_lstm[df_lstm.columns] = scaler.fit_transform(df_lstm[df_lstm.columns])
df_lstm.describe()
# Out:
#        Global_active_power       Voltage  Global_intensity  Sub_metering_1  \
# count         34685.000000  34685.000000      34685.000000    34685.000000
# mean             -0.699531      0.151530         -0.704330       -0.953650
# std               0.277138      0.228798          0.267858        0.145356
# min              -1.000000     -1.000000         -1.000000       -1.000000
# 25%              -0.931847      0.026604         -0.927068       -1.000000
# 50%              -0.783600      0.158825         -0.785270       -1.000000
# 75%              -0.550742      0.292273         -0.565280       -1.000000
# max               1.000000      1.000000          1.000000        1.000000
#
#        Sub_metering_2  Sub_metering_3         avg_t
# count    34685.000000    34685.000000  34951.000000
# mean        -0.944071       -0.401244     -0.212083
# std          0.179511        0.677681      0.391636
# min         -1.000000       -1.000000     -1.000000
# 25%         -1.000000       -0.939675     -0.514793
# 50%         -0.985642       -0.845321     -0.242604
# 75%         -0.971285        0.293117      0.076923
# max          1.000000        1.000000      1.000000

# %%
df_lstm.head(3)
# Out:
#                      Global_active_power   Voltage  Global_intensity  \
# DateTime
# 2006-12-16 17:00:00             0.273632 -0.324109          0.262315
# 2006-12-16 18:00:00             0.090090 -0.328998          0.082975
# 2006-12-16 19:00:00             0.018012 -0.432397          0.004304
#
#                      Sub_metering_1  Sub_metering_2  Sub_metering_3     avg_t
# DateTime
# 2006-12-16 17:00:00            -1.0       -0.977267        0.564836  0.029586
# 2006-12-16 18:00:00            -1.0       -0.710696        0.565352  0.029586
# 2006-12-16 19:00:00            -1.0       -0.938263        0.548337  0.029586

# %%
# def data_to_supervised(df, steps_ahead = 1, col_to_predict="Global_active_power"):
#     data = pd.DataFrame(df)
#     n_vars = data.shape[1]
#     columns = []
#     columns.append(data.shift(0))
#     # temp = data.shift(0)
#     columns.append(data.shift(-steps_ahead)[col_to_predict])
#     df_labeled = pd.concat(columns, axis=1)
#     names = [col + "(t-1)" for col in df.columns]
#     names.append(f"{col_to_predict}(t)")
#     print(names)
#     df_labeled.columns = names
#     df_labeled.dropna(inplace=True)
    
#     return df_labeled

def data_to_supervised(df, col_to_predict="Global_active_power"):
    data = pd.DataFrame(df)
    n_vars = data.shape[1]
    columns = []
    columns.append(data.shift(1))
    # temp = data.shift(0)
    columns.append(data.shift(0)[col_to_predict])
    df_labeled = pd.concat(columns, axis=1)
    names = [col + "(t-1)" for col in df.columns]
    names.append(f"{col_to_predict}(t)")
    print(names)
    df_labeled.columns = names
    df_labeled.dropna(inplace=True)
    
    return df_labeled

# %%
df_lstm = data_to_supervised(df_lstm)
df_lstm.head(5)
# Out:
# ['Global_active_power(t-1)', 'Voltage(t-1)', 'Global_intensity(t-1)', 'Sub_metering_1(t-1)', 'Sub_metering_2(t-1)', 'Sub_metering_3(t-1)', 'avg_t(t-1)', 'Global_active_power(t)']
#                      Global_active_power(t-1)  Voltage(t-1)  \
# DateTime
# 2006-12-16 18:00:00                  0.273632     -0.324109
# 2006-12-16 19:00:00                  0.090090     -0.328998
# 2006-12-16 20:00:00                  0.018012     -0.432397
# 2006-12-16 21:00:00                 -0.022901     -0.368025
# 2006-12-16 22:00:00                 -0.088806     -0.131166
#
#                      Global_intensity(t-1)  Sub_metering_1(t-1)  \
# DateTime
# 2006-12-16 18:00:00               0.262315                 -1.0
# 2006-12-16 19:00:00               0.082975                 -1.0
# 2006-12-16 20:00:00               0.004304                 -1.0
# 2006-12-16 21:00:00              -0.037781                 -1.0
# 2006-12-16 22:00:00              -0.100191                 -1.0
#
#                      Sub_metering_2(t-1)  Sub_metering_3(t-1)  avg_t(t-1)  \
# DateTime
# 2006-12-16 18:00:00            -0.977267             0.564836    0.029586
# 2006-12-16 19:00:00            -0.710696             0.565352    0.029586
# 2006-12-16 20:00:00            -0.938263             0.548337    0.029586
# 2006-12-16 21:00:00            -1.000000             0.557618    0.029586
# 2006-12-16 22:00:00            -0.982053             0.597834    0.029586
#
#                      Global_active_power(t)
# DateTime
# 2006-12-16 18:00:00                0.090090
# 2006-12-16 19:00:00                0.018012
# 2006-12-16 20:00:00               -0.022901
# 2006-12-16 21:00:00               -0.088806
# 2006-12-16 22:00:00               -0.354891

# %%
values = df_lstm.values

trainsize = 0.8
n_rows = round(len(values)*trainsize)
print(f"Taille du trainset : {n_rows}")

train = values[:n_rows, :]
test = values[n_rows:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D format as expected by LSTMs [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# Taille du trainset : 27661
# (27661, 1, 2) (27661,) (6915, 1, 2) (6915,)

# %%
model = Sequential()
#recurrent_activation ='selu' # 1er place
#recurrent_activation ='softsign' # 2e place

model.add(LSTM(125, input_shape=(train_X.shape[1], train_X.shape[2]),recurrent_activation ='sigmoid',activation='tanh',return_sequences=False))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh',return_sequences=True))
#model.add(LSTM(2*24,recurrent_activation ='sigmoid',activation='tanh'))
#model.add(Dropout(0.2))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

model.compile(loss='mean_absolute_error', optimizer='adam')
#model.compile(optimizer=tensorflow.keras.optimizers.SGD(learning_rate=0.001),
             # loss=tensorflow.keras.losses.MeanSquaredError(),
             # metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 125)               64000
#
#  dense_20 (Dense)            (None, 1)                 126
#
# =================================================================
# Total params: 64,126
# Trainable params: 64,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=75, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/75
# 396/396 - 2s - loss: 0.1857 - val_loss: 0.1177 - 2s/epoch - 5ms/step
# Epoch 2/75
# 396/396 - 1s - loss: 0.1326 - val_loss: 0.1158 - 889ms/epoch - 2ms/step
# Epoch 3/75
# 396/396 - 1s - loss: 0.1324 - val_loss: 0.1157 - 886ms/epoch - 2ms/step
# Epoch 4/75
# 396/396 - 1s - loss: 0.1322 - val_loss: 0.1157 - 887ms/epoch - 2ms/step
# Epoch 5/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 889ms/epoch - 2ms/step
# Epoch 6/75
# 396/396 - 1s - loss: 0.1321 - val_loss: 0.1157 - 890ms/epoch - 2ms/step
# Epoch 7/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 889ms/epoch - 2ms/step
# Epoch 8/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1156 - 884ms/epoch - 2ms/step
# Epoch 9/75
# 396/396 - 1s - loss: 0.1320 - val_loss: 0.1155 - 883ms/epoch - 2ms/step
# Epoch 10/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 888ms/epoch - 2ms/step
# Epoch 11/75
# 396/396 - 1s - loss: 0.1319 - val_loss: 0.1154 - 895ms/epoch - 2ms/step
# Epoch 12/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1154 - 880ms/epoch - 2ms/step
# Epoch 13/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 14/75
# 396/396 - 1s - loss: 0.1318 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 15/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1155 - 885ms/epoch - 2ms/step
# Epoch 16/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1153 - 897ms/epoch - 2ms/step
# Epoch 17/75
# 396/396 - 1s - loss: 0.1317 - val_loss: 0.1154 - 887ms/epoch - 2ms/step
# Epoch 18/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 874ms/epoch - 2ms/step
# Epoch 19/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1155 - 895ms/epoch - 2ms/step
# Epoch 20/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1153 - 887ms/epoch - 2ms/step
# Epoch 21/75
# 396/396 - 1s - loss: 0.1316 - val_loss: 0.1154 - 894ms/epoch - 2ms/step
# Epoch 22/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 882ms/epoch - 2ms/step
# Epoch 23/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1153 - 884ms/epoch - 2ms/step
# Epoch 24/75
# 396/396 - 1s - loss: 0.1315 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 25/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 893ms/epoch - 2ms/step
# Epoch 26/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 891ms/epoch - 2ms/step
# Epoch 27/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 898ms/epoch - 2ms/step
# Epoch 28/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1152 - 897ms/epoch - 2ms/step
# Epoch 29/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1151 - 884ms/epoch - 2ms/step
# Epoch 30/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 31/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1150 - 886ms/epoch - 2ms/step
# Epoch 32/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 33/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 34/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 35/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 884ms/epoch - 2ms/step
# Epoch 36/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 868ms/epoch - 2ms/step
# Epoch 37/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 38/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 882ms/epoch - 2ms/step
# Epoch 39/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 891ms/epoch - 2ms/step
# Epoch 40/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 41/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 902ms/epoch - 2ms/step
# Epoch 42/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 43/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 44/75
# 396/396 - 1s - loss: 0.1314 - val_loss: 0.1149 - 884ms/epoch - 2ms/step
# Epoch 45/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 899ms/epoch - 2ms/step
# Epoch 46/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 891ms/epoch - 2ms/step
# Epoch 47/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 48/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 49/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 885ms/epoch - 2ms/step
# Epoch 50/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 892ms/epoch - 2ms/step
# Epoch 51/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 878ms/epoch - 2ms/step
# Epoch 52/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 53/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 880ms/epoch - 2ms/step
# Epoch 54/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 888ms/epoch - 2ms/step
# Epoch 55/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 889ms/epoch - 2ms/step
# Epoch 56/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 882ms/epoch - 2ms/step
# Epoch 57/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1148 - 882ms/epoch - 2ms/step
# Epoch 58/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 59/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 60/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 898ms/epoch - 2ms/step
# Epoch 61/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 62/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 883ms/epoch - 2ms/step
# Epoch 63/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 887ms/epoch - 2ms/step
# Epoch 64/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 881ms/epoch - 2ms/step
# Epoch 65/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1149 - 894ms/epoch - 2ms/step
# Epoch 66/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 881ms/epoch - 2ms/step
# Epoch 67/75
# 396/396 - 1s - loss: 0.1312 - val_loss: 0.1148 - 883ms/epoch - 2ms/step
# Epoch 68/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 885ms/epoch - 2ms/step
# Epoch 69/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 895ms/epoch - 2ms/step
# Epoch 70/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 888ms/epoch - 2ms/step
# Epoch 71/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 897ms/epoch - 2ms/step
# Epoch 72/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 890ms/epoch - 2ms/step
# Epoch 73/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1150 - 887ms/epoch - 2ms/step
# Epoch 74/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 886ms/epoch - 2ms/step
# Epoch 75/75
# 396/396 - 1s - loss: 0.1313 - val_loss: 0.1149 - 875ms/epoch - 2ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
size = df_lstm.shape[1]-1
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], size))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.565

# %%
# print("test")
# Out:
# test

# %%
import sklearn
r2 = sklearn.metrics.r2_score(inv_y, inv_yhat)
print(r2)
r_adjusted = 1 - ( 1-r2 ) * ( len(test_y) - 1 ) / ( len(test_y) - test_X.shape[1] - 1 )
print(r_adjusted)
# Out:
# 0.4282967339033622
# 0.4281313105046074

# %%
aa=[x for x in range(100)]
plt.figure(figsize=(40,10))
plt.plot(aa, inv_y[:100], marker='.', label="actual")
plt.plot(aa, inv_yhat[:100], 'r', label="prediction")
plt.ylabel(df.columns[1], size=15)
plt.xlabel('Time step for first 500 hours', size=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # LSTM by Day

# %%
df_lstm = df.set_index('DateTime')
df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
df_lstm2 = df_lstm.resample('d').mean()
df_lstm2.head(5)
# Out:
#             Global_active_power     Voltage  Global_intensity  Sub_metering_1  \
# DateTime
# 2006-12-16             3.120298  236.152341         13.369524        0.000000
# 2006-12-17             2.354486  240.087028          9.999028        1.411806
# 2006-12-18             1.530435  241.231694          6.421667        0.738194
# 2006-12-19             1.157079  241.999313          4.926389        0.582639
# 2006-12-20             1.545658  242.308063          6.467361        0.000000
#
#             Sub_metering_2  Sub_metering_3  avg_t
# DateTime
# 2006-12-16        1.330159       12.692063   4.60
# 2006-12-17        2.907639        9.264583   2.40
# 2006-12-18        1.820139        9.734722   3.40
# 2006-12-19        5.279167        4.303472   1.25
# 2006-12-20        1.838889        9.765972   2.35

# %%
scaler2 = MinMaxScaler(feature_range=(-1,1))
df_lstm2[df_lstm2.columns] = scaler.fit_transform(df_lstm2[df_lstm2.columns])
df_lstm2.describe()
# Out:
#        Global_active_power      Voltage  Global_intensity  Sub_metering_1  \
# count          1442.000000  1442.000000       1442.000000     1442.000000
# mean             -0.414951     0.192797         -0.421490       -0.711124
# std               0.265431     0.247199          0.261236        0.282736
# min              -1.000000    -1.000000         -1.000000       -1.000000
# 25%              -0.583964     0.103188         -0.589880       -0.873827
# 50%              -0.420323     0.207230         -0.430347       -0.799090
# 75%              -0.273917     0.317815         -0.286551       -0.605023
# max               1.000000     1.000000          1.000000        1.000000
#
#        Sub_metering_2  Sub_metering_3        avg_t
# count     1442.000000     1442.000000  1453.000000
# mean        -0.691181       -0.285987    -0.211474
# std          0.343828        0.326046     0.391756
# min         -1.000000       -1.000000    -1.000000
# 25%         -0.928566       -0.513627    -0.514793
# 50%         -0.880998       -0.286380    -0.242604
# 75%         -0.551706       -0.071254     0.076923
# max          1.000000        1.000000     1.000000

# %%
df_lstm2 = data_to_supervised(df_lstm2)
df_lstm2.head(3)
# Out:
# ['Global_active_power(t-1)', 'Voltage(t-1)', 'Global_intensity(t-1)', 'Sub_metering_1(t-1)', 'Sub_metering_2(t-1)', 'Sub_metering_3(t-1)', 'avg_t(t-1)', 'Global_active_power(t)']
#             Global_active_power(t-1)  Voltage(t-1)  Global_intensity(t-1)  \
# DateTime
# 2006-12-16                  0.876122     -0.380415               0.900371
# 2006-12-17                  0.388504      0.100987               0.390452
# 2006-12-18                 -0.136197      0.241035              -0.150764
#
#             Sub_metering_1(t-1)  Sub_metering_2(t-1)  Sub_metering_3(t-1)  \
# DateTime
# 2006-12-16            -1.000000            -0.683636             0.513121
# 2006-12-17            -0.636286            -0.308448             0.073525
# 2006-12-18            -0.809824            -0.567099             0.133823
#
#             avg_t(t-1)  Global_active_power(t)
# DateTime
# 2006-12-16    0.029586                0.388504
# 2006-12-17   -0.491124               -0.136197
# 2006-12-18   -0.254438               -0.373925

# %%
values = df_lstm2.values

trainsize = 0.8
n_rows = round(len(values)*trainsize)
print(f"Taille du trainset : {n_rows}")

train = values[:n_rows, :]
test = values[n_rows:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D format as expected by LSTMs [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# Taille du trainset : 1140
# (1140, 1, 7) (1140,) (285, 1, 7) (285,)

# %%
model = Sequential()
model.add(LSTM(7, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 7)                 420
#
#  dense_10 (Dense)            (None, 1)                 8
#
# =================================================================
# Total params: 428
# Trainable params: 428
# Non-trainable params: 0
# _________________________________________________________________

# %%
#history = model.fit(train_X, train_y, epochs=75, batch_size=1, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
size = df_lstm.shape[1]-1
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], size))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_83531/3317972714.py in <module>
#       9 # make a prediction
#      10 yhat = model.predict(test_X)
# ---> 11 test_X = test_X.reshape((test_X.shape[0], size))
#      12 # invert scaling for forecast
#      13 inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
#
# ValueError: cannot reshape array of size 1995 into shape (285,6)

# %%
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)

# %%
import sklearn
r2 = sklearn.metrics.r2_score(inv_y, inv_yhat)
print(r2)
r_adjusted = 1 - ( 1-r2 ) * ( len(test_y) - 1 ) / ( len(test_y) - test_X.shape[1] - 1 )
print(r_adjusted)

# %%
aa=[x for x in range(100)]
plt.figure(figsize=(40,10))
plt.plot(aa, inv_y[:100], marker='.', label="actual")
plt.plot(aa, inv_yhat[:100], 'r', label="prediction")
plt.ylabel(df.columns[1], size=15)
plt.xlabel('Time step for first 500 days', size=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # LSTM by minute

# %%
df_lstm = df.set_index('DateTime')
# df_lstm = df_lstm.resample('h').mean()
df_lstm['Date'] = pd.to_datetime(df_lstm.index.date)
temperatures = pd.read_csv("pre_processing/temperatures.csv", parse_dates=['Date'], index_col='Date')
temperatures['avg_t'] = (temperatures['max_t'] - temperatures['min_t'])/2
df_lstm = df_lstm.join(temperatures, how="left", on='Date')
df_lstm = df_lstm.drop(columns=['Date','max_t','min_t'])
#df_lstm["Day"] = df_lstm.index.dayofweek+1
#y = pd.get_dummies(df_lstm.Day, prefix='Day')
#df_lstm = df_lstm.join(y, how="left")
#df_lstm = df_lstm.drop(columns=["Day"])
df_lstm = df_lstm.drop(columns=["Global_reactive_power"])
# df_lstm2 = df_lstm.resample('d').mean()
# df_lstm2.head(5)

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
df_lstm[df_lstm.columns] = scaler.fit_transform(df_lstm[df_lstm.columns])
df_lstm.describe()
# Out:
#        Global_active_power       Voltage  Global_intensity  Sub_metering_1  \
# count         2.081019e+06  2.081019e+06      2.081019e+06    2.081019e+06
# mean         -8.162308e-01  1.401197e-01     -8.163967e-01   -9.745238e-01
# std           1.901986e-01  2.080802e-01      1.832246e-01    1.389053e-01
# min          -1.000000e+00 -1.000000e+00     -1.000000e+00   -1.000000e+00
# 25%          -9.576317e-01  2.229402e-02     -9.502075e-01   -1.000000e+00
# 50%          -9.000543e-01  1.483037e-01     -8.921162e-01   -1.000000e+00
# 75%          -7.385479e-01  2.704362e-01     -7.427386e-01   -1.000000e+00
# max           1.000000e+00  1.000000e+00      1.000000e+00    1.000000e+00
#
#        Sub_metering_2  Sub_metering_3         avg_t
# count    2.081019e+06    2.081019e+06  2.075259e+06
# mean    -9.675367e-01   -5.837644e-01 -2.116362e-01
# std      1.446668e-01    5.408164e-01  3.905262e-01
# min     -1.000000e+00   -1.000000e+00 -1.000000e+00
# 25%     -1.000000e+00   -1.000000e+00 -5.147929e-01
# 50%     -1.000000e+00   -9.354839e-01 -2.426036e-01
# 75%     -9.750000e-01    9.677419e-02  7.692308e-02
# max      1.000000e+00    1.000000e+00  1.000000e+00

# %%
df_lstm = data_to_supervised(df_lstm)
df_lstm.head(3)
# Out:
# ['Global_active_power(t-1)', 'Voltage(t-1)', 'Global_intensity(t-1)', 'Sub_metering_1(t-1)', 'Sub_metering_2(t-1)', 'Sub_metering_3(t-1)', 'avg_t(t-1)', 'Global_active_power(t)']
#                      Global_active_power(t-1)  Voltage(t-1)  \
# DateTime
# 2006-12-16 17:24:00                 -0.250407     -0.247819
# 2006-12-16 17:25:00                 -0.043274     -0.326010
# 2006-12-16 17:26:00                 -0.040739     -0.347981
#
#                      Global_intensity(t-1)  Sub_metering_1(t-1)  \
# DateTime
# 2006-12-16 17:24:00              -0.244813                 -1.0
# 2006-12-16 17:25:00              -0.053942                 -1.0
# 2006-12-16 17:26:00              -0.053942                 -1.0
#
#                      Sub_metering_2(t-1)  Sub_metering_3(t-1)  avg_t(t-1)  \
# DateTime
# 2006-12-16 17:24:00               -0.975             0.096774    0.029586
# 2006-12-16 17:25:00               -0.975             0.032258    0.029586
# 2006-12-16 17:26:00               -0.950             0.096774    0.029586
#
#                      Global_active_power(t)
# DateTime
# 2006-12-16 17:24:00               -0.043274
# 2006-12-16 17:25:00               -0.040739
# 2006-12-16 17:26:00               -0.038204

# %%
values = df_lstm.values

trainsize = 0.80
n_rows = round(len(values)*trainsize)
print(f"Taille du trainset : {n_rows}")

train = values[:n_rows, :]
test = values[n_rows:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D format as expected by LSTMs [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# Taille du trainset : 27661
# (27661, 1, 7) (27661,) (6915, 1, 7) (6915,)

# %%
model = Sequential()
model.add(LSTM(3*60, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 180)               135360
#
#  dense_16 (Dense)            (None, 1)                 181
#
# =================================================================
# Total params: 135,541
# Trainable params: 135,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=5, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/5
# 16603/16603 - 49s - loss: 0.0031 - val_loss: 0.0065 - 49s/epoch - 3ms/step
# Epoch 2/5
# 16603/16603 - 48s - loss: 0.0026 - val_loss: 0.0033 - 48s/epoch - 3ms/step
# Epoch 3/5
# 16603/16603 - 48s - loss: 0.0025 - val_loss: 0.0021 - 48s/epoch - 3ms/step
# Epoch 4/5
# 16603/16603 - 48s - loss: 0.0025 - val_loss: 0.0023 - 48s/epoch - 3ms/step
# Epoch 5/5
# 16603/16603 - 48s - loss: 0.0025 - val_loss: 0.0021 - 48s/epoch - 3ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
size = df_lstm.shape[1]-1
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], size))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.251

# %%
import sklearn
r2 = sklearn.metrics.r2_score(inv_y, inv_yhat)
print(r2)
r_adjusted = 1 - ( 1-r2 ) * ( len(test_y) - 1 ) / ( len(test_y) - test_X.shape[1] - 1 )
print(r_adjusted)
# Out:
# 0.9174363691007426
# 0.9174349766088229

# %%
nbr_step = 100
aa=[x for x in range(nbr_step)]
plt.figure(figsize=(40,10))
plt.plot(aa, inv_y[:nbr_step], marker='.', label="actual")
plt.plot(aa, inv_yhat[:nbr_step], 'r', label="prediction")
plt.ylabel(df.columns[1], size=15)
plt.xlabel(f'Time step for first {nbr_step} time units', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
# data2 = df.set_index('DateTime')
# data2 = data2.resample('h').mean()

# %%
# data2
